# %% [markdown]
# # Victoria Public Transport Spatial Insights - Exploratory Analysis
#
# This notebook is a lightweight placeholder for portfolio exploration. The Streamlit app uses the processed sample files in `data/processed/`; full official extracts can be downloaded into `data/raw/` and transformed through the `src/` modules.

# %%
from pathlib import Path
import pandas as pd

base = Path('..')
stops = pd.read_csv(base / 'data' / 'processed' / 'sample_stops.csv')
patronage = pd.read_csv(base / 'data' / 'processed' / 'sample_patronage_long.csv', parse_dates=['date'])
lga = pd.read_csv(base / 'data' / 'processed' / 'sample_lga_access_summary.csv')

stops.head(), patronage.head(), lga.head()
